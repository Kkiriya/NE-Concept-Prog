# %% [markdown]
# ## Exercice 1 : Les itérables et la boucle for
#
# ### Exercice 1.1 : Parcours de liste
#
# Écrivez un programme qui parcourt une liste de fruits et affiche chaque fruit avec sa position.

# %%
fruit = ["pomme", "banane", "orange", "citron", "fraise"]

for f in fruit:
    print(f"fruit: {f}, position: {fruit.index(f)}")

# ou sinon
for f in range(len(fruit)):
    print(f"fruit: {fruit[f]}, position: {f}")
# Out:
# fruit: pomme, position: 0
# fruit: banane, position: 1
# fruit: orange, position: 2
# fruit: citron, position: 3
# fruit: fraise, position: 4
# fruit: pomme, position: 0
# fruit: banane, position: 1
# fruit: orange, position: 2
# fruit: citron, position: 3
# fruit: fraise, position: 4

# %% [markdown]
# ### Exercice 1.2 : Somme des éléments
#
# Créez un programme qui calcule la somme de tous les éléments d'une liste de nombres.

# %%
nombres = [1, 2, 3, 4, 5, 10, 11, 12, 13, 14, 15]
somme = 0

for n in nombres:
    somme += n

print(somme)
# Out:
# 90

# %% [markdown]
# ### Exercice 1.3 : Comptage de caractères
#
# Écrivez un programme qui compte combien de fois la lettre 'a' apparaît dans une chaîne de caractères.

# %%
str = "aaaabbfdssggskljhfaaaa"
count = 0

for s in str:
    if s == "a":
        count += 1

print(f"il y a {count} lettre a dans le string \"{str}\"")
# Out:
# il y a 8 lettre a dans le string "aaaabbfdssggskljhfaaaa"

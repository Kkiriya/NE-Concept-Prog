# %% [markdown]
# ## Exercice 6 : Code à Compléter - Combinaisons
#
# ### Exercice 6.1 : Maximum et minimum (À compléter)
#
# ```python
# temperatures = [22, 18, 25, 20, 17, 23, 19]
# max_temp = temperatures[0]
# min_temp = ______
#
# for temp in ______:
#     if temp > max_temp:
#         ______
#     if ______:
#         min_temp = temp
#
# print(f"Max: {max_temp}°C, Min: {min_temp}°C")
# ```

# %%
temperatures = [22, 18, 25, 20, 17, 23, 19]
max_temp = temperatures[0]
min_temp = temperatures[0]

for temp in temperatures:
    if temp > max_temp:
        max_temp = temp
    if temp < min_temp:
        min_temp = temp

print(f"Max: {max_temp}°C, Min: {min_temp}°C")
# Out:
# Max: 25°C, Min: 17°C

# %% [markdown]
# ### Exercice 6.2 : Palindrome (À compléter)
#
# ```python
# mot = "ressasser"
# est_palindrome = ______
#
# for i in range(______):
#     if mot[i] != mot[______]:
#         est_palindrome = False
#         ______
#
# if est_palindrome:
#     print(f"'{mot}' est un palindrome")
# else:
#     print(f"'{mot}' n'est pas un palindrome")
# ```

# %%
mot = "ressasser"
est_palindrome = True

for i in range(len(mot) // 2):
    if mot[i] != mot[len(mot) - 1 - i]:
        est_palindrome = False
        break

if est_palindrome:
    print(f"'{mot}' est un palindrome")
else:
    print(f"'{mot}' n'est pas un palindrome")
# Out:
# 'ressasser' est un palindrome

# %% [markdown]
# ### Exercice 6.3 : Jeu de devinette (À compléter)
#
# ```python
# secret = 42
# essais = 0
# max_essais = 3
#
# while ______:
#     essai = 30  # Simulation
#     ______
#
#     if essai == secret:
#         print("Gagné !")
#         ______
#     elif essai < secret:
#         print("Plus grand")
#     else:
#         print("Plus petit")
#
#     print(f"Essais restants: {max_essais - essais}")
#
# print(f"Perdu ! Le nombre était {secret}")
# ```

# %%
secret = 42
essais = 0
max_essais = 3

while essais < max_essais:
    essai = 30  # Simulation
    essais += 1

    if essai == secret:
        print("Gagné !")
        break
    elif essai < secret:
        print("Plus grand")
    else:
        print("Plus petit")

    print(f"Essais restants: {max_essais - essais}")

print(f"Perdu ! Le nombre était {secret}")
# Out:
# Gagné !
# Perdu ! Le nombre était 42

# %% [markdown]
# ### genuinely confused at wtf the code above is supposed to be so here's me making it make sense, Figured it out; turns out its confusing af cuz two different variables have the exact same name exept for one letter ;---; like why ? ?

# %%
secret = 42
essais = 0
max_essais = 3

while essais < max_essais:
    essais += 1
    guess = int(input("devinez un nombre entre 1 et 50: "))

    if guess == secret:
        print("Gagné !")
        break
    elif guess < secret:
        print("Plus grand")
    else:
        print("Plus petit")

    print(f"Essais restants: {max_essais - essais}")

    if essais == max_essais:
        print(f"Perdu ! Le nombre était {secret}")
# Out:
# Gagné !

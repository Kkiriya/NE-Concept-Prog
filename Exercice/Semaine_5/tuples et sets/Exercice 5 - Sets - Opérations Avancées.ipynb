# %% [markdown]
# ## Exercice 5 : Sets - Opérations Avancées
#
# ### 5.1 : Différences symétriques (À compléter)
#
# ```python
# preferences_user1 = {"action", "comedie", "drame"}
# preferences_user2 = {"comedie", "romance", "thriller"}
#
# # Films aimés par user1 mais pas user2
# seulement_user1 = ______
# # Films aimés par user2 mais pas user1
# seulement_user2 = ______
# # Films aimés par un seul des deux
# un_seul = ______
# # Tous les films uniques
# tous_films = ______
#
# print(f"Seulement user1: {seulement_user1}")
# print(f"Seulement user2: {seulement_user2}")
# print(f"Un seul: {un_seul}")
# print(f"Tous: {tous_films}")
# ```

# %%
preferences_user1 = {"action", "comedie", "drame"}
preferences_user2 = {"comedie", "romance", "thriller"}

# Films aimés par user1 mais pas user2
seulement_user1 = preferences_user1 - preferences_user2
# seulement_user1 = preferences_user1.difference(preferences_user2)

# Films aimés par user2 mais pas user1
seulement_user2 = preferences_user2 - preferences_user1
# seulement_user2 = preferences_user2.difference(preferences_user1)

# Films aimés par un seul des deux
un_seul = preferences_user1 ^ preferences_user2
# un_seul = preferences_user1.symmetric_difference(preferences_user2)

# Tous les films uniques
tous_films = preferences_user1 | preferences_user2
# tous_films = preferences_user1.union(preferences_user2)

print(f"Seulement user1: {seulement_user1}")
print(f"Seulement user2: {seulement_user2}")
print(f"Un seul: {un_seul}")
print(f"Tous: {tous_films}")
# Out:
# Seulement user1: {'drame', 'action'}
# Seulement user2: {'romance', 'thriller'}
# Un seul: {'action', 'thriller', 'romance', 'drame'}
# Tous: {'romance', 'comedie', 'drame', 'action', 'thriller'}

# %% [markdown]
# ### 5.2 : Vérification de sous-ensembles (Erreurs à corriger)
#
# ```python
# # Ce code vérifie mal les sous-ensembles
# competences_requises = {"python", "sql", "git"}
# competences_candidat = {"python", "git"}
#
# est_qualifie = competences_requises in competences_candidat
#
# if est_qualifie:
#     print("Candidat qualifié")
# else:
#     print("Compétences manquantes:", competences_requises - competences_candidat)
# ```

# %%
# Ce code vérifie mal les sous-ensembles
competences_requises = {"python", "sql", "git"}
competences_candidat = {"python", "git"}

est_qualifie = competences_requises <= competences_candidat
# est_qualifie = competences_requises.issubset(competences_candidat)

if est_qualifie:
    print("Candidat qualifié")
else:
    print("Compétences manquantes:", competences_requises - competences_candidat)
# Out:
# Compétences manquantes: {'sql'}

# %% [markdown]
# ### 5.3 : Mise à jour de sets (À compléter)
#
# ```python
# # Set initial
# nombres = {1, 2, 3}
#
# # Ajoutez plusieurs éléments avec update()
# ______
#
# # Effectuez une union avec un autre set
# autres_nombres = {6, 7, 8}
# ______
#
# # Gardez seulement l'intersection avec {2, 3, 4, 5}
# ______
#
# print(f"Set final: {nombres}")
# ```

# %%
# Set initial
nombres = {1, 2, 3}

# Ajoutez plusieurs éléments avec update()
nombres.update({4, 5})

# Effectuez une union avec un autre set
nombres |= {6,7,8}
# autres_nombres = {6, 7, 8}
# nombres.union(autres_nombres)

# Gardez seulement l'intersection avec {2, 3, 4, 5}
nombres &= {2, 3, 4, 5}
# nombres.intersection_update({2, 3, 4, 5})

print(f"Set final: {nombres}")
# Out:
# Set final: {2, 3, 4, 5}

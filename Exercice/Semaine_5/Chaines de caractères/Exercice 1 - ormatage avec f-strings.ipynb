# %% [markdown]
# # Exercices sur les Chaînes de Caractères
#
# ## Exercice 1 : Formatage avec f-strings
#
# ### 1.1 : Présentation personnelle
#
# Créez une présentation personnelle utilisant f-string avec variables.

# %%
nom = "Valade"
prenom = "Émile" 
print(f"Bonjour je m\'appelle {prenom} {nom}")
# Out:
# Bonjour je m'appelle Émile Valade

# %% [markdown]
# ### 1.2 : Calcul de prix
#
# Affichez un calcul de prix TTC avec formatage monétaire.

# %%
prix = 100
taxe = 0.15

print(f"{(prix + (prix*taxe)):.2f}$")
# Out:
# 115.00$

# %% [markdown]
# ### 1.3 : Table de multiplication
#
# Générez une table de multiplication formatée.

# %%
nbr = 5

for i in range(10):
    nbr_str = f"{i+1:2d}"
    resultat_str = f"{(i+1) * nbr:2d}"
    print(f"{nbr_str} * {nbr} = {resultat_str}")
# Out:
#  1 * 5 =  5
#  2 * 5 = 10
#  3 * 5 = 15
#  4 * 5 = 20
#  5 * 5 = 25
#  6 * 5 = 30
#  7 * 5 = 35
#  8 * 5 = 40
#  9 * 5 = 45
# 10 * 5 = 50

# %% [markdown]
# # Exercices sur les Dictionnaires en Python
#
# ## Exercice 1 : Déclaration et Création
#
# ### 1.1 : Déclaration basique (À compléter)
#
# ```python
# # Créez un dictionnaire représentant une personne avec:
# # - nom: "Dupont"
# # - age: 25
# # - ville: "Paris"
# personne = ______
#
# print(personne)
# ```

# %%
personne = {
    "nom": "Dupont",
    "age": 25,
    "ville": "Paris"
}

print(personne)
# Out:
# {'nom': 'Dupont', 'age': 25, 'ville': 'Paris'}

# %% [markdown]
# ### 1.2 : Depuis une liste de tuples (À compléter)
#
# ```python
# # Créez un dictionnaire à partir de cette liste de tuples
# donnees = [("nom", "Alice"), ("age", 30), ("metier", "ingenieure")]
# personne = ______
#
# print(personne)
# ```

# %%
donnees = [("nom", "alice"), ("age", 30), ("metier", "ingernieure")]
personne = dict(donnees)

print(personne)
# Out:
# {'nom': 'alice', 'age': 30, 'metier': 'ingernieure'}

# %% [markdown]
# ### 1.3 : Avec dict() (Erreurs à corriger)
#
# ```python
# # Ce code devrait créer un dictionnaire mais contient des erreurs
# etudiant = dict(
#     nom = "Martin"
#     prenom: "Pierre"
#     notes = [15, 18, 12]
# )
#
# print(etudiant)
# ```

# %%
etudiant = dict(
    nom = "Martin",
    prenom = "Pierre",
    notes = [15, 18, 12]
)

print(etudiant)
# Out:
# {'nom': 'Martin', 'prenom': 'Pierre', 'notes': [15, 18, 12]}

# %% [markdown]
# ## Exercice 2 : Accès aux Éléments
#
# ### 2.1 : Accès simple (À compléter)
#
# ```python
# livre = {
#     "titre": "1984",
#     "auteur": "George Orwell",
#     "annee": 1949,
#     "pages": 328
# }
#
# # Accédez au titre et à l'année
# titre = ______
# annee = ______
#
# print(f"'{titre}' publié en {annee}")
# ```

# %%
livre = {
    "titre": "1984",
    "auteur": "George Orwell",
    "annee": 1949,
    "pages": 328
}

# Accédez au titre et à l'année
titre = livre['titre']
annee = livre['annee']

print(f"'{titre}' publié en {annee}")
# Out:
# '1984' publié en 1949

# %% [markdown]
# ### 2.2 : Accès sécurisé (Erreurs à corriger)
#
# ```python
# # Ce code génère une erreur, corrigez-le
# config = {"host": "localhost", "port": 8080}
#
# print(f"Host: {config['host']}")
# print(f"Database: {config['database']}")
# print(f"Port: {config.get('port')}")
# ```

# %%
# Ce code génère une erreur, corrigez-le
config = {"host": "localhost", "port": 8080}

print(f"Host: {config['host']}")
print(f"Database: {config.get('database', 'Non spécifié')}")
print(f"Port: {config.get('port')}")
# Out:
# Host: localhost
# Database: Non spécifié
# Port: 8080

# %% [markdown]
# ### 2.3 : Valeurs par défaut (À compléter)
#
# ```python
# utilisateur = {"nom": "Alice", "age": 25}
#
# # Utilisez get() avec valeur par défaut
# ville = ______
# profession = ______
#
# print(f"Ville: {ville}")
# print(f"Profession: {profession}")
# ```

# %%
utilisateur = {"nom": "Alice", "age": 25}

# Utilisez get() avec valeur par défaut
ville = utilisateur.get('ville', 'Non spécifié')
profession = utilisateur.get('profession', 'Non spécifié')

print(f"Ville: {ville}")
print(f"Profession: {profession}")
# Out:
# Ville: Non spécifié
# Profession: Non spécifié
